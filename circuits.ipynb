# %% [markdown]
# # Circuits
#
# ***

# %% [markdown]
# The schemdraw package will draw circuits for us.

# %%
import schemdraw as sd
import schemdraw.logic as sdlog
import schemdraw.parsing as sdpar

# %% [markdown]
# ## Drawing by Hand
#
# ***
#
# https://schemdraw.readthedocs.io/en/latest/elements/logic.html

# %%
sdlog.And()

# %%
sdlog.Or()

# %%
sdlog.Not()

# %%
sdlog.Xor()

# %%
sdlog.Nand()

# %% [markdown]
# ## Using Parsing
#
# ***

# %%
sdpar.logicparse("not ((a and b) or c)")

# %% [markdown]
# ***
#
# ### End
